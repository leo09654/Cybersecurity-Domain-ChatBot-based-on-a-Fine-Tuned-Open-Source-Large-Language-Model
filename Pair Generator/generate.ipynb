# %% [markdown]
# Change Date Format

# %%
import json
from datetime import datetime

# Function to convert date format to full long date
def convert_to_full_long_date(date_str):
    date_obj = datetime.strptime(date_str, '%d/%m/%Y')
    return date_obj.strftime("%d %B %Y")

# Read JSON data from a file
with open('combined_cve_data.json', 'r') as file:
    data = json.load(file)

# Update the 'Published Date' in each record
for record in data:
    record['Published Date'] = convert_to_full_long_date(record['Published Date'])

# Convert back to JSON
updated_json = json.dumps(data, indent=4)
# print(updated_json)

# Optionally, write the updated data back to a file
with open('combined_cve_data_dated.json', 'w') as file:
    file.write(updated_json)

# %% [markdown]
# Generate the question-answer pairs

# %%
# DATA IS TRUNCATED FROM THE START FOR SECOND ITERATION

import json
import os
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv
import time

# Load environment variables
load_dotenv()

def read_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

def clean_description(item):
    item["Description"] = item["Description"].replace('\n', '').replace('\r', '').strip()
    return item

def clean_response(response):
    # Remove invalid control characters
    return ''.join(ch for ch in response if ch.isprintable() or ch in '\t\n\r')

def get_questions_answers(item):
    client = OpenAI(api_key=os.getenv("API_KEY"))

    prompt = f"The following is the information of a CVE:\n\n{json.dumps(item, indent=2)}\n\nPlease generate question and answer pairs for this information. Supplement the provided information with your own knowledge. Add code examples for this vulnerability in the answers if possible. Please also discuss possible attack scenarios of this vulnerability. Don't mention about the cut-off date of your own training data in the questions and answers. Dont mention in the questions and answers that a content for this vulnerability was provided to you. Always mention the CVE id in your questions.\n\nThe response should be in JSON format. Each set of question-answer pairs should be an object inside an array, with key-value pairs called 'question' and 'answer'. The parent key should be called 'data'."

    # Please generate question and answer pairs for this information. Supplement the provided information with your own knowledge. Add code examples for this vulnerability in the answers if possible. Please also discuss possible attack scenarios of this vulnerability. Don't mention about the cut-off date of your own training data in the questions and answers. Dont mention in the questions or answers that a content for this vulnerability was provided or not provided to you. If you dont want to describe something, dont mention anything about this content but say your reason generically always in this type of scenerio. Always mention the CVE id in your questions.\n\nThe response should be in JSON format. Each set of question-answer pairs should be an object inside an array, with key-value pairs called 'question' and 'answer'. The parent key should be called 'data'."



    try:
        completion = client.chat.completions.create(
            model="gpt-4-1106-preview",
            messages=[{'role': 'user', 'content': f"{prompt}"}],
            response_format={"type": "json_object"}
        )
        response = completion.choices[0].message.content.strip()
        clean_resp = clean_response(response)
        print(f"Tokens used in GPT-4-Turbo Response: {completion.usage.total_tokens}")
        return clean_resp
    except Exception as e:
        print(f"Error in GPT-4-Turbo API call: {e}")
        return None

def append_to_excel(qa_pairs, filename):
    df = pd.DataFrame(qa_pairs, columns=['Question', 'Answer'])
    if os.path.isfile(filename):
        book = pd.read_excel(filename)
        df = pd.concat([book, df], ignore_index=True)
    df.to_excel(filename, index=False)

def main(json_file_path, excel_file_path):
    data = read_json_file(json_file_path)

    for item in data:
        cleaned_item = clean_description(item)
        json_response = get_questions_answers(cleaned_item)
        if json_response:
            try:
                response_data = json.loads(json_response)
                qa_pairs = [(qa['question'], qa['answer']) for qa in response_data.get("data", [])]
                append_to_excel(qa_pairs, excel_file_path)
            except json.JSONDecodeError as e:
                print(f"JSON parsing error: {e}")
                print(f"Invalid JSON response: {json_response}")
        print("Taking a break for 5 seconds")
        time.sleep(5)

if __name__ == "__main__":
    json_file_path = 'combined_cve_data_dated.json'
    excel_file_path = 'output.xlsx'
    main(json_file_path, excel_file_path)
# Out:
# Tokens used in GPT-4-Turbo Response: 833
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 976
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 955
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1033
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 878
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 958
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 932
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 876
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1070
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 886
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 905
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 937
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 857
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 879
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 944
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1069
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 865
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 810
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 904
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 872
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 857
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 925
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 814
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 999
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 930
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 741
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 885
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 951
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 782
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 693
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1034
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 844
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 777
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 875
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 901
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 740
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1005
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 832
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 882
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 866
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 842
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 734
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 876
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 867
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 818
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 751
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 973
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 809
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 963
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 862
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 754
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 999
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 793
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 944
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1006
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 792
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 844
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 900
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1057
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1092
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 640
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 746
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 880
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 889
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 883
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 779
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 834
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 841
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 777
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 951
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 865
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 942
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 832
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 886
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 918
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 873
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 979
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 949
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 902
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 967
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 832
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 767
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 846
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 823
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 807
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 805
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 866
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 952
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 789
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 782
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 894
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 898
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 801
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 666
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 749
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1168
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 899
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1033
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 781
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1107
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 920
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1018
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 963
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 882
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 964
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 973
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1011
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1092
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1184
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1011
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 940
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1052
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 847
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 860
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 893
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 864
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 820
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 892
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 842
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 941
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 899
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 788
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1009
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 898
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 752
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 914
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 925
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 763
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 920
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 870
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 891
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 912
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 801
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1020
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 793
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 976
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 893
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 874
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 906
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 922
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 902
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 976
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 736
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1311
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 928
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 873
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 841
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 996
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1375
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1115
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 929
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1222
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 915
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1195
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1144
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 998
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1541
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1168
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1010
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1460
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1129
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 908
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1194
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1216
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 891
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 927
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1210
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1549
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1071
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 825
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 819
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 901
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1002
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1089
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 860
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 944
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1026
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 879
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 965
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 954
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 969
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1089
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1043
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1098
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1137
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1058
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 917
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1277
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1028
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 817
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1099
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 953
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1020
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1297
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1322
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1108
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1203
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1091
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1124
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1103
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 942
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1014
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1219
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1028
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1123
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 781
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 782
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 964
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1026
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 849
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1107
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1042
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1180
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1009
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1216
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 955
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1081
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1074
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1097
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1059
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1211
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1124
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1143
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1185
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1067
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1052
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 937
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1326
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1111
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1218
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1089
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1034
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1099
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1386
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1016
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 846
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1019
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 996
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 973
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1047
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1053
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 871
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1303
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 972
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1035
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1095
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1009
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 965
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1144
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1115
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 856
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 812
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1179
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1131
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 996
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 982
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 759
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 780
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 860
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 802
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 967
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 789
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1336
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1318
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1204
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1097
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1079
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1122
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1092
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1142
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1034
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1319
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 951
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1467
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1370
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1002
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 784
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1242
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 957
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 863
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 832
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 866
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 868
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1158
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 853
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1020
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 991
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1023
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1071
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1194
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1178
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 856
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1054
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 974
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 855
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1259
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 4460
# JSON parsing error: Expecting ':' delimiter: line 28 column 51 (char 1469)
# Invalid JSON response: {
#   "data": [
#     {
#       "question": "What is the CVE ID of the use-after-free vulnerability affecting multiple Apple operating systems?",
#       "answer": "The CVE ID of the use-after-free vulnerability is CVE-2023-32381."
#     },
#     {
#       "question": "Can you provide the description of CVE-2023-32381?",
#       "answer": "CVE-2023-32381 refers to a use-after-free issue that was resolved with improved memory management. This vulnerability could allow an app to execute arbitrary code with kernel privileges."
#     },
#     {
#
#       "question": "What is the severity score assigned to CVE-2023-32381?",
#       "answer": "The severity score assigned to CVE-2023-32381 is 7.8, which is classified as HIGH."
#     },
#     {
#       "question": "On what date was CVE-2023-32381 published?",
#       "answer": "CVE-2023-32381 was published on 27 July 2023."
#     },
#     {
#       "question": "Which Apple operating systems include fixes for CVE-2023-32381?",
#       "answer": "The following Apple operating systems include fixes for CVE-2023-32381: macOS Monterey 12.6.8, iOS 16.6, iPadOS 16.6, tvOS 16.6, macOS Big Sur 11.7.9, macOS Ventura 13.5, and watchOS 9.6."
#     },
#     {
#       "question": "Where can I find more information or support documents related to CVE-2023-32381?",
#       "answer": "You can find more information about CVE-2023-32381 in the support documents provided by Apple. The relevant URLs are:"
#        		,
#         "https://support.apple.com/en-us/HT213848"
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 826
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 767
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 762
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 779
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1347
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 743
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1245
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1115
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1247
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 991
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1164
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 942
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 807
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 922
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1032
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1095
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1111
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1128
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1239
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 990
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 973
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 870
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1084
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 912
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 861
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 875
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1054
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 979
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1089
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1095
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1021
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 974
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 877
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 929
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 931
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1120
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 905
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1226
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1142
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 838
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1188
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 834
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 896
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1162
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 986
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 941
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1019
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1030
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 987
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 930
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1086
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 935
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 739
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 658
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1365
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 765
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1062
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1115
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 953
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1007
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 912
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1068
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1081
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 982
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 966
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 941
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1098
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1289
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 804
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 993
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 952
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 981
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1015
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 992
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 917
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1039
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 951
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1072
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 906
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1023
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 931
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 904
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1066
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1041
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 875
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 967
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1060
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 884
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1067
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1054
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 802
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 856
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1056
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 858
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 901
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 905
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 920
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 913
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 963
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 870
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1141
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1084
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 913
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 839
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 982
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1001
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 915
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1259
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1157
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1162
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1250
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1150
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1007
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1147
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1040
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 950
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 913
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1040
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 934
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1164
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1040
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 843
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 921
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 919
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 974
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 821
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1026
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1087
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 805
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 901
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 815
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 911
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 842
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 961
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 949
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 998
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1081
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1134
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1123
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 973
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 985
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1097
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1052
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1189
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1031
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1110
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 874
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1044
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1142
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 999
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 956
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1049
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 817
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 943
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 953
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 868
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 930
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 800
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 890
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1017
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 971
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1014
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 795
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 846
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 829
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1231
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 872
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 935
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1007
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1221
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1171
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 877
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 897
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1244
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1336
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1136
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1122
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1280
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1125
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1165
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1330
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1051
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1036
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1331
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1034
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1127
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 992
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1111
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1416
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 991
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1055
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 991
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1480
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1178
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1106
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 866
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 957
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1037
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1122
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 991
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1145
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 758
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 933
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1215
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1104
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1273
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 809
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 920
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 987
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 802
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 870
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 871
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1013
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 658
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 970
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 921
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 942
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 776
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 888
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 876
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 911
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 972
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 953
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1188
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1283
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 795
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 877
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1050
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 895
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 849
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1136
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 791
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 935
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1234
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 979
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1197
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 979
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 822
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1020
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1091
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 956
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 974
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 680
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1078
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 951
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 886
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 835
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 842
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 969
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 947
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 950
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 826
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1013
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1012
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 933
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1103
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1131
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 974
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 936
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1232
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 939
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 700
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 954
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 821
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 911
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 838
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 918
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 736
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1119
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 819
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 985
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 793
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 898
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 950
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 778
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 879
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 704
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 796
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 769
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 966
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 837
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1135
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 980
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 930
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 893
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 878
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 908
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 903
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 839
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 911
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 910
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 885
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 937
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1176
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 959
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1136
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1100
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 990
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1006
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1088
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1289
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1063
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1021
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 954
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 971
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 954
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 989
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1357
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1572
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 874
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1077
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1229
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 965
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 940
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 834
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 936
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1084
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 852
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 941
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1022
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 883
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1034
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 892
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 974
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1119
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 962
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1031
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 975
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 885
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1148
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1089
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1103
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 883
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1121
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1118
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1061
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1033
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 978
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1147
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1157
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1004
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1251
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1035
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1171
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1191
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 944
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 875
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1097
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1112
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 900
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 927
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 948
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 970
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1152
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1270
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1160
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 933
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 969
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 989
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 944
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 990
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 945
# Taking a break for 5 seconds
# ...
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 912
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 878
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1099
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1036
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 989
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1005
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1008
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 970
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1008
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 967
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 872
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1191
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 762
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 825
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 842
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 874
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 929
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1076
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1024
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1121
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1428
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 798
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 831
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 889
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1195
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1123
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1066
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 943
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1093
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 874
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 939
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 788
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 947
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 871
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1099
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 932
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 874
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 787
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 818
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 813
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1315
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1054
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 805
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 904
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 904
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 763
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 871
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 948
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 933
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1074
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 711
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 754
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 921
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 862
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 725
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 863
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 759
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 714
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 876
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 690
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 901
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 671
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 709
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 773
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 620
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 814
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 872
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 781
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 854
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 932
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 844
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 677
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 834
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 891
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 773
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 833
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 938
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 891
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 795
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 777
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 812
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 653
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 708
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 733
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 774
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 764
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 800
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 770
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 810
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 805
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 688
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 838
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 907
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 721
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 803
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 846
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 840
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 960
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1073
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 838
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 856
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1025
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 959
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 924
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1096
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 970
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1340
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 890
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 958
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 964
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 977
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 836
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 768
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 934
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 935
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 864
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 773
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 902
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 954
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 996
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 809
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 890
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1342
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 766
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1071
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1025
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 759
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1108
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 941
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1007
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1204
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 931
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1020
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 695
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 692
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 864
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 852
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 852
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 800
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 966
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 801
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 885
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 777
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 758
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 864
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 864
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 712
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 880
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 876
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 808
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 836
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 888
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 727
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 832
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 767
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 813
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 788
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 758
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 675
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1100
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1091
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1004
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1154
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 927
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1311
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 943
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 820
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1322
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 808
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 940
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 895
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 866
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1139
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 935
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 941
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 937
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 901
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 902
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 922
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 844
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 798
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1007
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 917
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 766
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 942
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 742
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1005
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1121
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 713
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 917
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 755
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 716
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 752
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 812
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 776
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 690
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 758
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 922
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 703
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 795
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 787
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 890
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 848
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 855
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1087
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 950
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 843
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 798
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 670
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1040
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1362
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 899
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 986
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1155
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1010
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 764
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 794
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 866
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 902
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 999
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 967
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 980
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1129
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1108
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1174
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 1198
# Taking a break for 5 seconds
# Tokens used in GPT-4-Turbo Response: 843
# Taking a break for 5 seconds
